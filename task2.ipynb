# %% [markdown]
# <a href="https://colab.research.google.com/github/octet07/task2/blob/main/task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df= pd.read_csv('/content/drive/MyDrive/AIML/day4/titanic.csv')

# %% [markdown]
# 1. Generate summary statistics (mean, median, std, etc.).

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.median(numeric_only=True)
# Out:
# PassengerId    446.0000
# Survived         0.0000
# Pclass           3.0000
# Age             28.0000
# SibSp            0.0000
# Parch            0.0000
# Fare            14.4542
# dtype: float64

# %%
df.mean(numeric_only=True)
# Out:
# PassengerId    446.000000
# Survived         0.383838
# Pclass           2.308642
# Age             29.699118
# SibSp            0.523008
# Parch            0.381594
# Fare            32.204208
# dtype: float64

# %% [markdown]
# 2. Create histograms and boxplots for numeric features.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
numeric_cols = ['Age', 'Fare', 'SibSp', 'Parch']

# %%
print("Histograms:")
df[numeric_cols].hist(figsize=(12, 8), bins=20, edgecolor='black')
plt.tight_layout()
plt.show()
# Out:
# Histograms:

# %%
print("Boxplots:")
plt.figure(figsize=(12, 8))
for i, col in enumerate(numeric_cols):
    plt.subplot(2, 2, i + 1)
    sns.boxplot(data=df, y=col, color='skyblue')
    plt.title(f'Boxplot of {col}')
plt.tight_layout()
plt.show()
# Out:
# Boxplots:

# %% [markdown]
# 3. Use pairplot/correlation matrix for feature relationships.

# %%
corr_matrix = df.corr(numeric_only=True)
plt.figure(figsize=(10, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5, fmt=".2f")
plt.title("Correlation Matrix of Numeric Features")
plt.show()

# %%
selected_features = ['Survived', 'Pclass', 'Age', 'Fare', 'SibSp', 'Parch']
sns.pairplot(df[selected_features], hue='Survived', diag_kind='kde', corner=True)
plt.suptitle(" Pairplot of Selected Features by Survival", y=1.02)
plt.show()

# %% [markdown]
# 3.Identify patterns, trends, or anomalies in the data.

# %%
# Survival count
sns.countplot(x='Survived', data=df)
plt.title("Survival Count")
plt.show()

# Survival by sex
sns.countplot(x='Sex', hue='Survived', data=df)
plt.title("Survival by Sex")
plt.show()

# Age distribution by survival
sns.kdeplot(data=df[df['Survived'] == 1]['Age'].dropna(), label='Survived')
sns.kdeplot(data=df[df['Survived'] == 0]['Age'].dropna(), label='Did Not Survive')
plt.title("Age Distribution by Survival")
plt.show()

# %% [markdown]
# Inferences
#
#
# *   majority of passengers did not survive
# *   females survives more than males
# *   lower age ranges had more chances of survival like children
